# %% [markdown]
# # Final figure

# %%
import seaborn
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ga = [1.012, 1.009, 1.001, 1.019, 1.005, 1.026, 1.042]
rs = [1.004, 1.023, 1.0, 1.036, 1.004, 1.053, 1.063]
ts = [1.005, 1.02, 1.002, 1.032, 1.008, 1.058, 1.063]
best_data = np.array([rs, ga, ts]).T
best_data
# Out:
# array([[ 1.004,  1.012,  1.005],
#        [ 1.023,  1.009,  1.02 ],
#        [ 1.   ,  1.001,  1.002],
#        [ 1.036,  1.019,  1.032],
#        [ 1.004,  1.005,  1.008],
#        [ 1.053,  1.026,  1.058],
#        [ 1.063,  1.042,  1.063]])

# %%
fig = plt.figure(figsize=(13, 5))
problems = ["vrpnc1", "vrpnc2", "vrpnc12", "vrpnc3", "vrpnc11", "vrpnc4", "vrpnc5"]
algorithms = ["random savings", "genetic algorithm", "tabu search"]
seaborn.heatmap(best_data, annot=True, vmin=1., vmax=1.1, fmt=".4", xticklabels=algorithms, yticklabels=problems)
plt.xlabel("methodss")
plt.ylabel("problem instance")
plt.title("Best values divided by best known values")
savefig("../../presentation/figs/best_values.png")
