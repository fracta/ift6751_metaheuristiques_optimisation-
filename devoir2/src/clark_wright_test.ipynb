# %%
# %pylab inline
import pyximport
pyximport.install(reload_support=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (None, <pyximport.pyximport.PyxImporter at 0x7f4bc5ed9610>)

# %%
import clark_wright
import cvrp
import benchmark
import progress_bar
from routes import Route, steepest_improvement

# %%
data = cvrp.read_vrp("../lit_instances/vrpnc3.txt")
prob = cvrp.CVRPProblem(data)
routes = [Route([0, i, 0], prob.weights[i]) for i in range(1, prob.num_clients+1)]
print prob
# Out:
# Constrained Vehicule Routing Problem (CVRP)
# 100 clients, Q = 200.0

# %%
# %time sols = clark_wright.monte_carlo(routes, 200, 5, prob.distance_matrix, prob.vehicle_capacity)
scores = map(lambda x: benchmark.get_distance(x, prob.distance_matrix, prob.weights), sols)
zipped = zip(sols, scores)
# Out:
# [-------------------------] 0% Monte Carlo
# [-------------------------] 1% Monte Carlo
# [-------------------------] 1% Monte Carlo
# [-------------------------] 2% Monte Carlo
# [#------------------------] 2% Monte Carlo
# [#------------------------] 3% Monte Carlo
# [#------------------------] 3% Monte Carlo
# [#------------------------] 4% Monte Carlo
# [#------------------------] 4% Monte Carlo
# [#------------------------] 5% Monte Carlo
# [#------------------------] 5% Monte Carlo
# [#------------------------] 6% Monte Carlo
# [##-----------------------] 6% Monte Carlo
# [##-----------------------] 7% Monte Carlo
# [##-----------------------] 7% Monte Carlo
# [##-----------------------] 8% Monte Carlo
# [##-----------------------] 8% Monte Carlo
# [##-----------------------] 9% Monte Carlo
# [##-----------------------] 9% Monte Carlo
# [##-----------------------] 10% Monte Carlo
# [###----------------------] 10% Monte Carlo
# [###----------------------] 11% Monte Carlo
# ...

# %%
sorted_solutions = sorted(zipped, key=lambda x:x[1])

for i in range(4):
    benchmark.print_solution(prob.positions, prob.distance_matrix, prob.weights, sorted_solutions[i][0])
